# %%
import os
import shutil
import glob
from tqdm import tqdm

# %%
Raw_DIR = r'C:\Users\Muhammad Talha\Desktop\Final\mrlEyes_2018_01'
for dirpath, diename, filenames in os.walk(Raw_DIR):
    for i in tqdm([f for f in filenames if f.endswith('.png')]):
        if i.split('_')[4] == '0':
            shutil.copy(src = dirpath+'/'+i, dst=r'C:\Users\Muhammad Talha\Desktop\Final\PreparedData\train\closeEye')
        elif i.split('_')[4] == '1':
            shutil.copy(src = dirpath+'/'+i, dst=r'C:\Users\Muhammad Talha\Desktop\Final\PreparedData\train\openEye')
# Out:
# 0it [00:00, ?it/s]
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 10257/10257 [02:24<00:00, 70.85it/s]
